# %% [markdown]
# ### Dotazování na server
#
# ---
#
# Abychom mohli s údaji, které jsou k dispozici na webu, pracovat, je potřeba získat konkretní `html` soubor.
#
# <br>
#
# Tento proces za nás obyčejně obstarává prohlížeč, protože vzdálený server o příslušné `html` (`css` + `js` soubory) požádá.
#
# <br>
#
# #### Python odesílá požadavky
#
# ---
#
# Stejně jako náš prohlížeč, tak můžeme Python instruovat, aby pro nás provedl to stejné, co prohlížeč.
#
# <br>
#
# Tedy vytvořil požadavek na serveru a obratem získal odpověď obsahující data.
#
# <br>
#
# Pomocí knihovny `requests` (příp. i dalších jiných) můžeme posílat požadavky typu:
# 1. **get**
# 2. **post**
# 3. **put**
#
# <br>
#
# Který budete používat vy záleží na webu, se kterým pracujete. Opět si ukážeme přímo v prohlížeči.
#
# <br>
#
# #### Requests, funkce `get`
#
# ---
# Pomocí požadavku `get` dostaneme obvykle jako odpověď HTML kód k vyhteslení stránky.
#
# Vyzkoušíme si odeslání požadavku na tento [server](https://www.bezrealitky.cz/). Nejprve však na žádoucí stránce opět kliknout pravým tlačítkem myši a vybrat v prohlížeči `inspect element`.
#
# <br>
#
# Následně se objeví na spodu stránky lišta, ve které najdeme v záhlaví možnost `network` (tady sledujeme jakou metodu prohlížeč používá při komunikaci se serverem):

# %%
import requests       # nejprve instalace, potom import
# GET  = precist
# PUT  = update
# POST = insert
# DELETE
from pprint import pprint
import json

# %%
dir(requests)
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'JSONDecodeError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet_version',
#  'charset_normalizer_version',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
# ...

# %%
help(requests.get)   # výpis nápovědy
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
dir(requests)         # dostupné metody
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'JSONDecodeError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet_version',
#  'charset_normalizer_version',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
# ...

# %% [markdown]
# - [Vyhledávání Bezrealitky Prostějov](https://www.bezrealitky.cz/vyhledat#offerType=prodej&estateType=dum%2Cbyt%2Cpozemek&disposition=&ownership=&construction=&equipped=&balcony=&order=timeOrder_desc&boundary=%7B%22type%22%3A%22Feature%22%2C%22properties%22%3A%7B%7D%2C%22geometry%22%3A%7B%22type%22%3A%22Polygon%22%2C%22coordinates%22%3A%5B%5B%5B16.737716%2C49.5433642%5D%2C%5B16.7475195%2C49.5430971%5D%2C%5B16.7564865%2C49.5448626%5D%2C%5B16.7594921%2C49.5425077%5D%2C%5B16.7706483%2C49.5430513%5D%2C%5B16.7793138%2C49.5407389%5D%2C%5B16.7821104%2C49.538163%5D%2C%5B16.7945753%2C49.533909%5D%2C%5B16.807043%2C49.5331636%5D%2C%5B16.8122893%2C49.5368092%5D%2C%5B16.8134955%2C49.5359281%5D%2C%5B16.8115939%2C49.5347359%5D%2C%5B16.8124196%2C49.5339539%5D%2C%5B16.8205232%2C49.5339369%5D%2C%5B16.8216265%2C49.5321152%5D%2C%5B16.825665%2C49.5345463%5D%2C%5B16.8329476%2C49.5323039%5D%2C%5B16.8308491%2C49.5302432%5D%2C%5B16.8247014%2C49.5290436%5D%2C%5B16.8150318%2C49.5317975%5D%2C%5B16.8065286%2C49.5285944%5D%2C%5B16.8014405%2C49.5239956%5D%2C%5B16.8043481%2C49.5221205%5D%2C%5B16.806259%2C49.516692%5D%2C%5B16.8053411%2C49.5125661%5D%2C%5B16.7971354%2C49.5107053%5D%2C%5B16.7927205%2C49.512645%5D%2C%5B16.7878691%2C49.5098413%5D%2C%5B16.790738%2C49.5063658%5D%2C%5B16.7880278%2C49.5029519%5D%2C%5B16.7880888%2C49.499523%5D%2C%5B16.7844321%2C49.4968929%5D%2C%5B16.7918226%2C49.493125%5D%2C%5B16.7887297%2C49.4876808%5D%2C%5B16.7892024%2C49.4856241%5D%2C%5B16.7924637%2C49.4841405%5D%2C%5B16.7928137%2C49.4794501%5D%2C%5B16.7976821%2C49.4751991%5D%2C%5B16.7979903%2C49.4735972%5D%2C%5B16.7955468%2C49.4726956%5D%2C%5B16.7974771%2C49.4713952%5D%2C%5B16.796774%2C
# %%
url = "https://www.idnes.cz/"

# %%
odpoved_get = requests.get(url)
if odpoved_get.status_code != 200:  # neni OK  napriklad 404
    quit() # sys.exit()
type(odpoved_get)
# Out:
# requests.models.Response

# %%
dir(odpoved_get)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
type(odpoved_get)
# Out:
# requests.models.Response

# %%
odpoved_get
# Out:
# <Response [200]>

# %%
print(odpoved_get.status_code)
# Out:
# 200

# %%
# requests.get(url).text

# %%
type(odpoved_get.text)
# Out:
# str

# %%
len(odpoved_get.text)
# Out:
# 21409

# %%
pprint(odpoved_get.text)
# Out:
# ('<!doctype html>\r\n'
#  '<html>\r\n'
#  '<head>\r\n'
#  '    \r\n'
#  '    \r\n'
#  '\r\n'
#  '<script>var Unidata = { "exdomena": null, "ostrov": "idnes", "rubrika": '
#  '"idnes", "zobrazeni": "home", "verze": "B", "score": "idnes-DFB", "reklama": '
#  'true, "timestamp": 1724944929118.0, "webtype": "full", "section": "other", '
#  '"subSection": "", "pageType": "default", "authors": [""], "keywords": [], '
#  '"isLogged": false, "noAd": 0, "lidskost": 263965370323838\r\n'
#  '    };\r\n'
#  "        var pp_gemius_extraparameters = new Array('content=free', "
#  "'premium=false', 'verze=B', 'webtype=full');\r\n"
#  '    \r\n'
#  '</script>\r\n'
#  '\r\n'
#  '    \r\n'
#  '    <meta charset="windows-1250">\r\n'
#  '\t<meta http-equiv="cache-control" content="no-cache">\r\n'
#  '\t\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<meta name="viewport" content="width=1030">\r\n'
#  '\r\n'
#  '<title>iDNES.cz &#8211; s n&#225;mi v&#237;te v&#237;c</title>\r\n'
#  '\r\n'
# ...

# %% [markdown]
# #### Raw html
#
# ---
# Vidíme, že podoba, kterou nyní `html` získalo, neni moc užitečná. Protože s `html` budeme chtít podrobně pracovat a vyhledávat v něm, musíme vrácené údaje zpracovat (rozdělit~parsovat).<br />
#
# Toho dosáhneme opět použitím vhodné knihovny, která nám práci usnadní. Mrkněte na [pypi.org](https://pypi.org/).

# %% [markdown]
# <br>
#
# ### Komunikace s API, funkce `post`
#
# ---
# Web API = application programming interface, slouží ke komunikaci se serverem, požadavky jsou na server odeslány ve formátu XML nebo JSON.
#
# Funkce `post` umožňuje odeslat na server konkrétní dotaz, např. na získání výsledů vehledávání, výpis a úpravu databáze a podobně.
#
# Ukážeme si na příkladu s testovacím webem [Reqres.in](https://reqres.in/)
#
# <br>
#
# #### Získání seznamu uživatelů pomocí `get`

# %%
# API

# %%
url = "https://reqres.in/api/users"
api_get = requests.get(url)

# %%
api_get.text
# Out:
# '{"page":1,"per_page":6,"total":12,"total_pages":2,"data":[{"id":1,"email":"george.bluth@reqres.in","first_name":"George","last_name":"Bluth","avatar":"https://reqres.in/img/faces/1-image.jpg"},{"id":2,"email":"janet.weaver@reqres.in","first_name":"Janet","last_name":"Weaver","avatar":"https://reqres.in/img/faces/2-image.jpg"},{"id":3,"email":"emma.wong@reqres.in","first_name":"Emma","last_name":"Wong","avatar":"https://reqres.in/img/faces/3-image.jpg"},{"id":4,"email":"eve.holt@reqres.in","first_name":"Eve","last_name":"Holt","avatar":"https://reqres.in/img/faces/4-image.jpg"},{"id":5,"email":"charles.morris@reqres.in","first_name":"Charles","last_name":"Morris","avatar":"https://reqres.in/img/faces/5-image.jpg"},{"id":6,"email":"tracey.ramos@reqres.in","first_name":"Tracey","last_name":"Ramos","avatar":"https://reqres.in/img/faces/6-image.jpg"}],"support":{"url":"https://reqres.in/#support-heading","text":"To keep ReqRes free, contributions towards server costs are appreciated!"}}'
# ...

# %% [markdown]
# Převedení odpovědi do `json`

# %%
# Jakou funkci pouziji na nacteni?
import json 
uzivatele_json = json.loads(api_get.text)
uzivatele_json
# Out:
# {'page': 1,
#  'per_page': 6,
#  'total': 12,
#  'total_pages': 2,
#  'data': [{'id': 1,
#    'email': 'george.bluth@reqres.in',
#    'first_name': 'George',
#    'last_name': 'Bluth',
#    'avatar': 'https://reqres.in/img/faces/1-image.jpg'},
#   {'id': 2,
#    'email': 'janet.weaver@reqres.in',
#    'first_name': 'Janet',
#    'last_name': 'Weaver',
#    'avatar': 'https://reqres.in/img/faces/2-image.jpg'},
#   {'id': 3,
#    'email': 'emma.wong@reqres.in',
#    'first_name': 'Emma',
#    'last_name': 'Wong',
#    'avatar': 'https://reqres.in/img/faces/3-image.jpg'},
#   {'id': 4,
#    'email': 'eve.holt@reqres.in',
#    'first_name': 'Eve',
#    'last_name': 'Holt',
#    'avatar': 'https://reqres.in/img/faces/4-image.jpg'},
#   {'id': 5,
#    'email': 'charles.morris@reqres.in',
#    'first_name': 'Charles',
#    'last_name': 'Morris',
#    'avatar': 'https://reqres.in/img/faces/5-image.jpg'},
#   {'id': 6,
#    'email': 'tracey.ramos@reqres.in',
#    'first_name': 'Tracey',
# ...

# %% [markdown]
# <br>
#
# #### Přidání nového uživatele pomocí `post`

# %%
url = "https://reqres.in/api/users"
params = {"name": "Ondra",
          "job": "Lektor"}

# %%
odpoved_post = requests.post(url, params)
print(odpoved_post.text)
# Out:
# {"name":"Ondra","job":"Lektor","id":"648","createdAt":"2024-08-29T15:22:34.474Z"}

# %% [markdown]
# **Dynamický html**

# %%
import requests 

url = "https://www.scrapingcourse.com/javascript-rendering"
result = requests.get(url)

# %%
with open("dynamic.txt", mode="w") as f: 
    f.write(result.text)
