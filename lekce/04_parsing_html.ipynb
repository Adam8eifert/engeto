# %% [markdown]
# ### Beautifulsoup
#
# ---
#
# Asi jeden z těch nejznámějších parserů určených k rozdělování `html`, `xml` atd. Opět musíme nejprve nainstalovat (jedná se o balíček třetí strany).
#
# <br>
#
# V našem virtuálním pracovním prostředí:
# ```bash
# $ pip3 install beautifulsoup4
# $ pip3 freeze > requirements.txt
# ```
#
# <br>
#
# #### Vstupní hodnoty
#
# ---

# %%
import requests  # pip install requests
# import bs4  
# bs4.BeautifulSoup
from bs4 import BeautifulSoup

# %%
cislo = 1
url = f"https://heroes3.cz/hraci/index.php?page={cislo}&order=&razeni=DESC"
jmeno_souboru = f"vystup_tab_{cislo}.csv"

# %% [markdown]
# <br>
#
# #### Odeslání požadavku
#
# ---

# %%
odp_serveru = requests.get(url)

# %%
type(odp_serveru.text)
# Out:
# str

# %%
len(odp_serveru.text)
# Out:
# 28080

# %%
odp_serveru.status_code
# Out:
# 200

# %%
print(odp_serveru.text[200:])
# Out:
# roes of Might and Magic 3, Heroes 3, liga, turnaje, online, hra, HoMaM, HMM, Hamachi, GameRanger" />
# <title>Liga Heroes 3 - Hráči</title>
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" crossorigin="anonymous"><link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/common.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/menu.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/footer.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/ramecky.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/nova_hra.css" />
# <link rel="shortcut icon" href="https://heroes3.cz/favicon.png"  type="image/x-icon" />
# </head>
# <body>
# <div id="div_logo"></div>
# <div id="div_main">
# <div id="div_menu"><ul>
# ...

# %% [markdown]
# <br>
#
# #### Parsování html
#
# ---

# %%
help(BeautifulSoup)
# Out:
# Help on class BeautifulSoup in module bs4:
#
# class BeautifulSoup(bs4.element.Tag)
#  |  BeautifulSoup(markup='', features=None, builder=None, parse_only=None, from_encoding=None, exclude_encodings=None, element_classes=None, **kwargs)
#  |
#  |  A data structure representing a parsed HTML or XML document.
#  |
#  |  Most of the methods you'll call on a BeautifulSoup object are inherited from
#  |  PageElement or Tag.
#  |
#  |  Internally, this class defines the basic interface called by the
#  |  tree builders when converting an HTML/XML document into a data
#  |  structure. The interface abstracts away the differences between
#  |  parsers. To write a new tree builder, you'll need to understand
#  |  these methods as a whole.
#  |
#  |  These methods will be called by the BeautifulSoup constructor:
#  |    * reset()
#  |    * feed(markup)
#  |
#  |  The tree builder may call these methods from its feed() implementation:
# ...

# %%
BeautifulSoup(odp_serveru.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="cs">
# <head>
# <meta charset="utf-8"/>
# <meta content="Liga a turnaje v počítačové hře Heroes of Might and Magic III." name="description"/>
# <meta content="Heroes of Might and Magic 3, Heroes 3, liga, turnaje, online, hra, HoMaM, HMM, Hamachi, GameRanger" name="keywords"/>
# <title>Liga Heroes 3 - Hráči</title>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" rel="stylesheet"/><link href="https://heroes3.cz/_include/css/common.css" rel="Stylesheet" type="text/css">
# <link href="https://heroes3.cz/_include/css/menu.css" rel="Stylesheet" type="text/css"/>
# <link href="https://heroes3.cz/_include/css/footer.css" rel="Stylesheet" type="text/css"/>
# <link href="https://heroes3.cz/_include/css/ramecky.css" rel="Stylesheet" type="text/css"/>
# ...

# %%
type(BeautifulSoup(odp_serveru.text))
# Out:
# bs4.BeautifulSoup

# %%
dir(BeautifulSoup(odp_serveru.text))  # int("2")
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
# ...

# %%
# Jednodussi priklad
html_doc = """
<html>
<head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
</body>
</html>
"""

# %%
BeautifulSoup(html_doc)   # int("2")
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
type(BeautifulSoup(html_doc))
# Out:
# bs4.BeautifulSoup

# %%
soup = BeautifulSoup(html_doc)
soup
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.__dir__()
# Out:
# ['element_classes',
#  'builder',
#  'is_xml',
#  'known_xml',
#  '_namespaces',
#  'parse_only',
#  'markup',
#  'original_encoding',
#  'declared_html_encoding',
#  'contains_replacement_characters',
#  'parser_class',
#  'name',
#  'namespace',
#  'prefix',
#  'attrs',
#  'contents',
#  'parent',
#  'previous_element',
#  'next_element',
#  'next_sibling',
#  'previous_sibling',
#  'hidden',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'preserve_whitespace_tags',
#  'interesting_string_types',
#  'current_data',
#  'currentTag',
#  'tagStack',
#  'open_tag_counter',
#  'preserve_whitespace_tag_stack',
#  'string_container_stack',
#  '_most_recent_element',
#  '__module__',
#  '__doc__',
#  'ROOT_TAG_NAME',
#  'DEFAULT_BUILDER_FEATURES',
#  'ASCII_SPACES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  '__init__',
#  '_clone',
#  '__getstate__',
#  '__setstate__',
#  '_decode_markup',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_feed',
#  'reset',
#  'new_tag',
# ...

# %%
soup
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
soup.b
# Out:
# <b>The Dormouse's story</b>

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
soup.head
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
type(soup.a)
# Out:
# bs4.element.Tag

# %%
soup.name
# Out:
# '[document]'

# %%
soup.p.name
# Out:
# 'p'

# %%
type(soup.name)
# Out:
# str

# %%
soup
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
soup.head
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.a  # but how to get the rest?
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all("a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all("a")[1]
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
type(soup.find_all("a"))
# Out:
# bs4.element.ResultSet

# %%
list(soup.find_all("a"))
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(["a", "b"])
# Out:
# [<b>The Dormouse's story</b>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
# Get all children
soup.body.contents
# Out:
# ['\n',
#  <p class="title"><b>The Dormouse's story</b></p>,
#  '\n',
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  '\n',
#  <p class="story">...</p>,
#  '\n']

# %%
type(soup.body.contents)
# Out:
# list

# %%
soup.body.contents[1]
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.head.contents
# Out:
# [<title>The Dormouse's story</title>]

# %%
soup.contents
# Out:
# ['\n',
#  <html>
#  <head><title>The Dormouse's story</title></head>
#  <body>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>
#  </html>,
#  '\n']

# %%
# Also children; what is the difference?
soup.body.children

# %%
iter(soup.contents)

# %%
for c in soup.body.contents:  # iter(soup.contents)
    print(c)  # next()
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
#
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#
#
# <p class="story">...</p>

# %%
for c in soup.body.children:  # iter(soup.contents)
    print(c)  # next()
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
#
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#
#
# <p class="story">...</p>

# %%
type(soup.body.children)  # iterovatelny & ITERATOR
# Out:
# list_iterator

# %%
type(soup.body.contents)  # iterovatelny (seznam)
# Out:
# list

# %%
type(soup.body.children), type(soup.body.contents)
# Out:
# (list_iterator, list)

# %%
next(soup.body.children)
# Out:
# '\n'

# %%
i = iter([1, 2, 3])
while True:
    next(i)

# for _ in [1, 2, 3]: ...
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[55], line 3
#       1 i = iter([1, 2, 3])
#       2 while True:
# ----> 3     next(i)
#       5 # for _ in [1, 2, 3]: ...
#
# StopIteration:

# %%
import sys 

sys.getsizeof(soup.body.contents)  # list
# Out:
# 120

# %%
sys.getsizeof(soup.body.children)  # iterator
# Out:
# 48

# %%
list(soup.body.children)
# Out:
# ['\n',
#  <p class="title"><b>The Dormouse's story</b></p>,
#  '\n',
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  '\n',
#  <p class="story">...</p>,
#  '\n']

# %%
soup.body.contents
# Out:
# ['\n',
#  <p class="title"><b>The Dormouse's story</b></p>,
#  '\n',
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  '\n',
#  <p class="story">...</p>,
#  '\n']

# %%
all_a_tags_from_second_para = soup.body.contents[3].contents
all_a_tags_from_second_para
# Out:
# ['Once upon a time there were three little sisters; and their names were\n',
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  ',\n',
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  ' and\n',
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  ';\nand they lived at the bottom of a well.']

# %%
soup.body.contents[3].contents[1].string
# Out:
# 'Elsie'

# %%
soup.body.contents[1].contents[0].contents[0]
# Out:
# "The Dormouse's story"

# %%
soup
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
soup.body.contents[1].contents[0].string
# Out:
# "The Dormouse's story"

# %%
# .strings(): look only on text
for string in soup.strings:
    if string == "\n":
        continue
    print(string)
# Out:
# The Dormouse's story
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
#
# Elsie
# ,
#
# Lacie
#  and
#
# Tillie
# ;
# and they lived at the bottom of a well.
# ...

# %%
# Opposite way: parent
tag = soup.body.contents[1].contents[0]
tag
# Out:
# <b>The Dormouse's story</b>

# %%
tag.parent
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
tag.parent.parent.parent
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
tag.parent.parent.parent.parent
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
type(tag.parent.parent.parent), type(tag.parent.parent.parent.parent)
# Out:
# (bs4.element.Tag, bs4.BeautifulSoup)

# %%
html_tag = soup.html
html_tag
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
# all the way to the Soup
html_tag.parent, type(html_tag.parent)
# Out:
# (
#  <html>
#  <head><title>The Dormouse's story</title></head>
#  <body>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>
#  </html>,
#  bs4.BeautifulSoup)

# %%
# Cesta dolu:
# * .contents (list)
# * .children (iterator)

# Cesta nahoru:
# * .parent  (nez potkame objekt typu bs4.BeautifulSoup)

# %%
tag
# Out:
# <b>The Dormouse's story</b>

# %%
current_tag = tag 
while True:
    print(type(current_tag))
    current_tag = current_tag.parent
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.BeautifulSoup'>
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 4
#       2 while True:
#       3     print(type(current_tag))
# ----> 4     current_tag = current_tag.parent
#
# AttributeError: 'NoneType' object has no attribute 'parent'

# %%
tag = soup.body.contents[1].contents[0]   # nas tag "<b>"

# %%
for p in tag.parents:
    print(p)
    print("-"*10)
    print()
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# ----------
#
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# ----------
#
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# ...

# %%
# siblings

# %%
soup
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
tag = soup.p  
tag
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
tag.next_sibling
# Out:
# '\n'

# %%
tag.next_sibling.next_sibling
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
tag.next_sibling.next_sibling.next_sibling.next_sibling
# Out:
# <p class="story">...</p>

# %%
tag.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling

# %%
tag.next_sibling.next_sibling.children

# %%
tag.next_sibling.next_sibling.contents[-2]
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
print(tag.previous_sibling)

# %%
soup
# Out:
# <html>
# <head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %%
soup.prettify()
# Out:
# '<html>\n <head>\n  <title>\n   The Dormouse\'s story\n  </title>\n </head>\n <body>\n  <p class="title">\n   <b>\n    The Dormouse\'s story\n   </b>\n  </p>\n  <p class="story">\n   Once upon a time there were three little sisters; and their names were\n   <a class="sister" href="http://example.com/elsie" id="link1">\n    Elsie\n   </a>\n   ,\n   <a class="sister" href="http://example.com/lacie" id="link2">\n    Lacie\n   </a>\n   and\n   <a class="sister" href="http://example.com/tillie" id="link3">\n    Tillie\n   </a>\n   ;\nand they lived at the bottom of a well.\n  </p>\n  <p class="story">\n   ...\n  </p>\n </body>\n</html>\n'

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
# Heroes example follows

# %%
# zpatky k strance
# soup from get request
# odp_serveru = requests.get("....")
soup = BeautifulSoup(odp_serveru.text, 'html.parser')

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="cs">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Liga a turnaje v počítačové hře Heroes of Might and Magic III." name="description"/>
#   <meta content="Heroes of Might and Magic 3, Heroes 3, liga, turnaje, online, hra, HoMaM, HMM, Hamachi, GameRanger" name="keywords"/>
#   <title>
#    Liga Heroes 3 - Hráči
#   </title>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" rel="stylesheet"/>
#   <link href="https://heroes3.cz/_include/css/common.css" rel="Stylesheet" type="text/css">
#    <link href="https://heroes3.cz/_include/css/menu.css" rel="Stylesheet" type="text/css"/>
#    <link href="https://heroes3.cz/_include/css/footer.css" rel="Stylesheet" type="text/css"/>
#    <link href="https://heroes3.cz/_include/css/ramecky.css" rel="Stylesheet" type="text/css"/>
# ...

# %% [markdown]
# <br>
#
# #### Selekce tabulky s atributem `tab_top`
#
# ---

# %%
table_tag_top = soup.find("table", {"class": "tab_top"})  # <table></table>

# %%
type(table_tag_top)
# Out:
# bs4.element.Tag

# %%
print(table_tag_top.prettify())
# Out:
# <table class="tab_top">
#  <tr>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#     POŘADÍ
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#     SKUPINA
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=jmeno&amp;razeni=DESC">
#     JMÉNO
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#     BODY
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=elo&amp;razeni=DESC">
#     ELO
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=vitezstvi&amp;razeni=DESC">
#     VÍTĚZSTVÍ
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=celkem_her&amp;razeni=DESC">
#     CELKEM HER
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=uspesnost&amp;razeni=DESC">
#     ÚSPĚŠNOST
#    </a>
#   </th>
#   <th>
# ...

# %% [markdown]
# <br>
#
# Jakmile máme celou tabulku, snažíme se rozptyl zmenšit a najít pouze tagy s jednotlivými hráči. Vidíme, že každý hráč je na řádku. Dále, že každý řádek je schovaný za tagem `tr`.
#
# <br>
#
# #### Selekce elementů `tr`, řádků
#
# ---

# %%
vsechny_tr = table_tag_top.find_all("tr")

# %%
vsechny_tr[0]
# Out:
# <tr>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">POŘADÍ</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">SKUPINA</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=jmeno&amp;razeni=DESC">JMÉNO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">BODY</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=elo&amp;razeni=DESC">ELO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=vitezstvi&amp;razeni=DESC">VÍTĚZSTVÍ</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=celkem_her&amp;razeni=DESC">CELKEM HER</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=uspesnost&amp;razeni=DESC">ÚSPĚŠNOST</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=registrace&amp;razeni=DESC">REGISTRACE</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=karma&amp;razeni=DESC">KARMA</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=prispevky&amp;razeni=DESC">PŘÍSPĚVKY</a></th>
# ...

# %%
vsechny_tr[1]
# Out:
# <tr>
# <td class="right">1.</td>
# <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img alt="Šampion" src="https://heroes3.cz/_include/img/skupiny/1.png" style="cursor: help;" title="Šampion"/></div></td>
# <td><a href="https://heroes3.cz/hraci/detail.php?id=5131">Pepix</a></td>
# <td class="right">0</td>
# <td class="right">1876</td>
# <td class="right">138</td>
# <td class="right">244</td>
# <td class="right">57%</td>
# <td class="right">16. 2. 2016</td>
# <td class="right">147</td>
# <td class="right">647</td>
# </tr>

# %%
vsechny_tr[3]
# Out:
# <tr>
# <td class="right">3.</td>
# <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/></div></td>
# <td><a href="https://heroes3.cz/hraci/detail.php?id=3113">Scooby</a></td>
# <td class="right">0</td>
# <td class="right">1999</td>
# <td class="right">301</td>
# <td class="right">437</td>
# <td class="right">69%</td>
# <td class="right">29. 12. 2012</td>
# <td class="right">119</td>
# <td class="right">1278</td>
# </tr>

# %%
type(vsechny_tr)
# Out:
# bs4.element.ResultSet

# %%
dir(vsechny_tr)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort',
#  'source']

# %%
print(vsechny_tr[0])
# Out:
# <tr>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">POŘADÍ</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">SKUPINA</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=jmeno&amp;razeni=DESC">JMÉNO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">BODY</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=elo&amp;razeni=DESC">ELO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=vitezstvi&amp;razeni=DESC">VÍTĚZSTVÍ</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=celkem_her&amp;razeni=DESC">CELKEM HER</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=uspesnost&amp;razeni=DESC">ÚSPĚŠNOST</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=registrace&amp;razeni=DESC">REGISTRACE</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=karma&amp;razeni=DESC">KARMA</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=prispevky&amp;razeni=DESC">PŘÍSPĚVKY</a></th>
# ...

# %%
print(vsechny_tr[1])
# Out:
# <tr>
# <td class="right">1.</td>
# <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img alt="Šampion" src="https://heroes3.cz/_include/img/skupiny/1.png" style="cursor: help;" title="Šampion"/></div></td>
# <td><a href="https://heroes3.cz/hraci/detail.php?id=5131">Pepix</a></td>
# <td class="right">0</td>
# <td class="right">1876</td>
# <td class="right">138</td>
# <td class="right">244</td>
# <td class="right">57%</td>
# <td class="right">16. 2. 2016</td>
# <td class="right">147</td>
# <td class="right">647</td>
# </tr>

# %%
type(vsechny_tr[1])
# Out:
# bs4.element.Tag

# %% [markdown]
# <br>
#
# Na začátku máme **záhlaví** (index `0`), bez toho se obejdeme, stačí aplikovat _slicing_, které datový typ `ResultSet` podporuje.
#
# <br>
#
# Nyní, když umíme rozdělit html na jednotlivé řádky (s jednotlivými hráči), potřebujeme konečně izolovat jednotlivé buňky, které obsahují konkrétní údaje.
#
# <br>
#
# #### Selekce jednotlivých buněk `td`
#
# ---

# %%
table_tag_top = soup.find("table", {"class": "tab_top"})  # <table></table>
vsechny_tr = table_tag_top.find_all("tr")
for tr in vsechny_tr[1:]:             # vynechame zahlavi, budeme mit vlastni
    td_na_radku = tr.find_all("td")
    print(td_na_radku[2].text, td_na_radku[5].text)
    #print(td_na_radku[4].get_text())  # pozor, seznam buněk
    break                             # po první iteraci ukončíme
# Out:
# Pepix 138

# %%
print(td_na_radku)
# Out:
# [<td class="right">1.</td>, <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img alt="Šampion" src="https://heroes3.cz/_include/img/skupiny/1.png" style="cursor: help;" title="Šampion"/></div></td>, <td><a href="https://heroes3.cz/hraci/detail.php?id=5131">Pepix</a></td>, <td class="right">0</td>, <td class="right">1876</td>, <td class="right">138</td>, <td class="right">244</td>, <td class="right">57%</td>, <td class="right">16. 2. 2016</td>, <td class="right">147</td>, <td class="right">647</td>]

# %%
print(td_na_radku[2].get_text())
# Out:
# Pepix

# %%
print(td_na_radku[2].text)
# Out:
# Pepix

# %%
print(td_na_radku[2].string)
# Out:
# Pepix

# %%
print(td_na_radku[2].getText())
# Out:
# Pepix

# %%
# **.string vs .text**
# <td>some text</td>
# <td></td>
# <td><p>more text</p></td>
# <td>even <p>more text</p></td>

# .string:
# some text
# None
# more text
# None

# .text:
# some text
# ""
# more text
# even more text

# %%
def vyber_atributy_z_radku(td_na_radku: "bs4.element.ResultSet") -> dict:
    """
    Z kazdeho radku (tr) vyber urcite bunky (td)[index])
    a zabal je do slovniku
    
    :return: dict
    """
    return {
        "poradi": td_na_radku[0].get_text(),
        "jmeno": td_na_radku[2].get_text(),
        "vitezstvi": td_na_radku[5].get_text(),
        "celkem_her": td_na_radku[6].get_text()
    }

# %%
# klasický for loop
table_tag_top = soup.find("table", {"class": "tab_top"})  # <table></table>
vsechny_tr = table_tag_top.find_all("tr")
vysledky = []  # list[dict]
for tr in vsechny_tr[1:]:
    td_na_radku = tr.find_all("td")
    data_hrace = vyber_atributy_z_radku(td_na_radku)
    vysledky.append(data_hrace)

# %%
vysledky
# Out:
# [{'poradi': '1.', 'jmeno': 'Pepix', 'vitezstvi': '138', 'celkem_her': '244'},
#  {'poradi': '2.', 'jmeno': 'H34D', 'vitezstvi': '413', 'celkem_her': '563'},
#  {'poradi': '3.', 'jmeno': 'Scooby', 'vitezstvi': '301', 'celkem_her': '437'},
#  {'poradi': '4.', 'jmeno': 'siska96', 'vitezstvi': '89', 'celkem_her': '159'},
#  {'poradi': '5.',
#   'jmeno': 'naoblaku',
#   'vitezstvi': '127',
#   'celkem_her': '316'},
#  {'poradi': '6.', 'jmeno': 'SD', 'vitezstvi': '514', 'celkem_her': '737'},
#  {'poradi': '7.', 'jmeno': 'Kacer', 'vitezstvi': '146', 'celkem_her': '229'},
#  {'poradi': '8.', 'jmeno': 'Unreal', 'vitezstvi': '295', 'celkem_her': '381'},
#  {'poradi': '9.', 'jmeno': 'maGe', 'vitezstvi': '215', 'celkem_her': '363'},
#  {'poradi': '10.',
#   'jmeno': 'Lord Slayer',
#   'vitezstvi': '149',
#   'celkem_her': '433'},
#  {'poradi': '11.',
#   'jmeno': 'KekelZpekel',
#   'vitezstvi': '308',
#   'celkem_her': '404'},
#  {'poradi': '12.',
#   'jmeno': 'DavidHakl',
# ...

# %% [markdown]
# <br>
#
# Podobně jako u řetězit built-in funkce `print(type(...))` můžeme řetězit uživatelské funkce.

# %%
# zkrácený zápis
data_o_hracich = list()

for tr in vsechny_tr[1:]:
    data_o_hracich.append(vyber_atributy_z_radku(tr.find_all("td")))

# %% [markdown]
# <br>
#
# Nyní umíme sbírat jednotlivé položky u všech hráčů, takže můžeme aplikovat stejný postup na celý `ResultSet` s použitím *list comprehension*.

# %%
# list comprehensions
data_o_hracich = [
    vyber_atributy_z_radku(tr.find_all("td"))
    for tr in vsechny_tr[1:]
]

# %%
data_o_hracich[0]  # list[dict]
# Out:
# {'poradi': '1.', 'jmeno': 'Pepix', 'vitezstvi': '138', 'celkem_her': '244'}

# %% [markdown]
# <br>
#
# #### Ukládání údajů do souboru
#
# ---
#
# Úplně nakonec chceme námi posbírané údaje uložit ve formátu `csv` do příslušného souboru:

# %%
vysledky[0].keys()
# Out:
# dict_keys(['poradi', 'jmeno', 'vitezstvi', 'celkem_her'])

# %%
import csv
import traceback


def zapis_data(data: list, jmeno_souboru: str) -> str:
    """
    Zkus zapsat udaje z par. 'data' do souboru formatu .csv.
    """
    try:
        csv_soubor = open(jmeno_souboru, mode="w", encoding="utf-8")
        sloupce = data[0].keys()   
    except FileExistsError:
        print("Cannot create file")
    #     return traceback.format_exc()
    except IndexError:
        print("Cannot read data")
    #     return traceback.format_exc()
    else:
        zapis = csv.DictWriter(csv_soubor, fieldnames=sloupce)
        zapis.writeheader()
        zapis.writerows(data)
        return "Saved"
    finally:
        csv_soubor.close()

# %%
vysledky[0]
# Out:
# {'poradi': '1.', 'jmeno': 'Pepix', 'vitezstvi': '138', 'celkem_her': '244'}

# %%
jmeno_souboru
# Out:
# 'vystup_tab_1.csv'

# %%
print(vysledek := zapis_data(vysledky, jmeno_souboru))
# Out:
# Saved

# %% [markdown]
# <br>
#
# #### Vyzkoušíme další tabulky
#
# ---
#
# Pokud vám správně funguje varianta pro první tabulku, zkuste vkládat odkazy pro další tabulky, resp. tabulky další v pořadí.
#
# <br>
#
# Případně můžete zapsat tento proces pomocí programu v Pythonu, který lze spouštět s různými argumenty (první pro číslo tabulky, druhý pro jméno výstupu v `csv`).

# %%
cislo = 2

# %% [markdown]
# ### S velkou mocí příchází velká zodpovědnost
#
# ---
#
# 1. Než se pustíme do scrapingu, zkontolujeme `robots.txt` (allow/disallow)
# 2. Zkontrolujeme, jestli služba nenabízí API (není třeba scrapovat, ale využít endpoint)
# 3. Nezatěžujeme server velkým množstvím dotazů v krátkém časovém horizontu (pád->blokování)
# 4. Nepoužívám cizí data ke komerčním účelům (_pravidla&podmínky_)
# 5. requests, bs4, urllib.requests, htmlparser, requests-html, scrapy, selenium, aj.
#
# <br>
#
# ### Závěrem
#
# ---
#
# <br>
#
# #### Kam dál?
# 1. Dejte tomu čas, nechte to sednout,
# 2. projít ještě jednou jednotlivé lekce a úlohy,
# 3. komunikace v rámci Slacku,
# 4. aktualizace [portálu learn.engeto.com](https://learn.engeto.com) úpravy, nové úkoly, teorie.
#
# <br>
#
# #### Jak se zdokonalovat?
# 1. Čtení + psaní + diskuze (Slack zůstává aktivní),
# 2. svatá trojice (*algorithm, data structures, libraries*),
# 3. **nekopírujte projekty ostatních!** Vymyslete, co by se mohlo vám/vašim známým hodit.
#
# <br>
#
# #### Je libo přitvrdit?
# 1. Git, přík.řádek, IDE, textové editory, virt. prostředí, SQL, pip3, OOP, další knihovny,..
# 2. pokračovat v další teorii jenom pokud si budete v základních a mírně pokročilých pojmech jistější,
# 3. Kurz **datové analýzy**,
# 4. **OOP Python**.
#
# <br>
#
# #### Komunita?
# 1. [pyvo](https://pyvo.cz/) - organizování setkání po celé Čoro
# 2. [junior.guru](https://junior.guru/jobs/) (autor: Honza Javorek)
# 3. [příručka o hledání první práce v IT](https://junior.guru/candidate-handbook/) (autor: Honza Javorek)
#
# ---
